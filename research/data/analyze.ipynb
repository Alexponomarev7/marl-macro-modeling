# %% [markdown]
# # Analyze data

# %%
# %load_ext autoreload
# %autoreload 2

from research.data.utils import plot_data_file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
_ = plot_data_file("Aguiar_Gopinath_2007", sample_id=1)
# Out:
# periods: 1000.0
# persistence_gov_spending: 0.7216404497596873
# persistence_productivity: 0.784909233954199
# capital_share: 0.31811066095562324
# risk_aversion: 1.9913334503454942
# debt_share: 0.09112323041312756
# shock_gov_spending_std: 0.03750240024712005
# labor_share: 0.3587125420941387
# discount_rate: 0.9638108709925127
# capital_adjustment_cost: 2.1507148615618843
# depreciation: 0.03250670116987168
# shock_productivity_std: 0.003962933186362245
# elasticity_substitution: 0.001375274644327777
