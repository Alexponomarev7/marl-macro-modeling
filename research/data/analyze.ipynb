# %% [markdown]
# # Analyze data

# %%
# %load_ext autoreload
# %autoreload 2

from research.data.utils import plot_data_file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
_ = plot_data_file("Aguiar_Gopinath_2007", sample_id=7, n_iters=50)
# Out:
# alpha: 0.5468484558509381
# beta: 0.9667217633804748
# delta: 0.06954965270342164
# periods: 50
# start_capital: 0.9360020242274437
