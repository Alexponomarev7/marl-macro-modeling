# %% [markdown]
# # Analyze data

# %%
# %load_ext autoreload
# %autoreload 2

from research.data.utils import plot_data_file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
_ = plot_data_file("Aguiar_Gopinath_2007", sample_id=1)
# Out:
# periods: 1000.0
# persistence_gov_spending: 0.897007292924996
# persistence_productivity: 0.8024137610682931
# capital_share: 0.37053901505439313
# risk_aversion: 1.6747909115538626
# debt_share: 0.12349571397685871
# shock_gov_spending_std: 0.02175342864823665
# labor_share: 0.34680212444935127
# discount_rate: 0.9660302099935296
# capital_adjustment_cost: 3.339503311427258
# depreciation: 0.04750770815018984
# shock_productivity_std: 0.0053475221316751
# elasticity_substitution: 0.0014555170036323062

# %%
_ = plot_data_file("Aguiar_Gopinath_2007", sample_id=2)
# Out:
# periods: 1000.0
# persistence_gov_spending: 0.860355977090326
# persistence_productivity: 0.9063970065394427
# capital_share: 0.32655065509904024
# risk_aversion: 1.530013667863675
# debt_share: 0.12937728179497573
# shock_gov_spending_std: 0.02336712421438794
# labor_share: 0.30885967763854755
# discount_rate: 0.9859870981341352
# capital_adjustment_cost: 5.606066456069687
# depreciation: 0.040570439360205116
# shock_productivity_std: 0.004692691394306067
# elasticity_substitution: 0.000568020544688258
