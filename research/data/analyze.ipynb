# %% [markdown]
# # Analyze data

# %%
# %load_ext autoreload
# %autoreload 2

from research.data.utils import plot_data_file
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
_ = plot_data_file("Aguiar_Gopinath_2007", sample_id=7, n_iters=50)
# Out:
# beta: 0.9608198864330595
# capital_adjustment_cost: 2.4179821701396023
# capital_share: 0.3684043097194799
# debt_share: 0.05519024415686781
# depreciation: 0.03195556288002262
# elasticity_substitution: 0.0005170073144740146
# labor_share: 0.32875918663027787
# periods: 50
# persistence_gov_spending: 0.9271665734068923
# persistence_productivity: 0.8012727143185523
# risk_aversion: 1.8431977837467906
# shock_gov_spending_std: 0.03162478658510447
# shock_productivity_std: 0.0042871070748836315
